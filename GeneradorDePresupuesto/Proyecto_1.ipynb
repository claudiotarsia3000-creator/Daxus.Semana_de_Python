# %% [markdown]
# # print("texto_aqui")
# * Imprimimos Texto por consola
# * "HOLA MUNDO"
# * Impresiones VARIAS

# %%
print ("¡Hola Mundo!")
print (2 + 3)
print ("El resultado de 2 + 3 es:", 2 + 3)

nombre = "Alice"
print ("Hola", nombre)
edad = 30
print (nombre, "tiene", edad, "años.")
# Out:
# ¡Hola Mundo!
# 5
# El resultado de 2 + 3 es: 5
# Hola Alice
# Alice tiene 30 años.

# %% [markdown]
# # RECIBIR DATOS DE USUARIO
# * Imprimimos Texto por consola

# %%
nombre = input("Introduce tu nombre: ")
print("¡Hola, " + nombre + "! Bienvenido a la Semana de Python en la práctica.")
nombre = "Semana de Python en la práctica"
print(nombre)
# Out:
# ¡Hola, Klauss! Bienvenido a la Semana de Python en la práctica.
# Semana de Python en la práctica

# %% [markdown]
# # TIPOS DE DATOS
# * Imprimimos Tipo de dato por consola

# %%
nombre = "Juan"
print(nombre)
print(type(nombre))
# Out:
# Juan
# <class 'str'>

# %%
Valor = 1
print(Valor)
print(type(Valor))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# # CONVERSION DE TIPO
# * Imprimimos TIPO por consola

# %%
valor = 10 
valor_texto = str(valor)
print(type(valor_texto))

valor = 1000
valor_numerico = int(valor)
print(type(valor_numerico))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# # CALCULOS BASICOS
# * Multiplicacion
# * Division
# * Suma
# * Resta

# %%
# SUMA 
a = 5
b = 3
suma = a + b
print("La suma de", a, "y", b, "es:", suma)

# RESTA
resta = a - b
print("La resta de", a, "y", b, "es:", resta)

# MULTIPLICACIÓN
multiplicacion = a * b
print("La multiplicación de", a, "y", b, "es:", multiplicacion)
      
# DIVISIÓN
division = a / b
print("La división de", a, "y", b, "es:", division)
# Out:
# La suma de 5 y 3 es: 8
# La resta de 5 y 3 es: 2
# La multiplicación de 5 y 3 es: 15
# La división de 5 y 3 es: 1.6666666666666667

# %% [markdown]
# # PROYECTO

# %%
# Instalar la biblioteca fpdf

# !pip  install fpdf
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40760 sha256=89bb28004d78b947385217fda4c5c6655ea52ef1e7069bf4adca5c420c5998a4
#   Stored in directory: /Users/klausstattoo/Library/Caches/pip/wheels/77/a7/ad/85c9cac940930d61dad2d2bf19c550f172d2d7ec7c3c17af2a
# Successfully built fpdf
# ...

# %% [markdown]
# # PRESUPUESTO PARA UN PROYECTO
# * Creando un PDF

# %%
# Presupuesto para un proyecto
from fpdf import FPDF

# Solicitar información al usuario
proyecto = input("Ingrese la descripción del proyecto: ")
horas_estimadas = input("Ingrese el total de horas estimadas: ")
valor_hora = input("Introduzca el valor de la hora trabajada: ")
termino = input("Introduzca el tiempo estimado de finalización: ")

# Calcular el valor total del proyecto
valor_total = int(horas_estimadas) * int(valor_hora)

# Crear el PDF
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial")

# Agregar la plantilla de fondo
pdf.image("template.png", x=0, y=0)

# Agregar el texto al PDF
pdf.text(115, 145, proyecto)
pdf.text(115, 160, horas_estimadas)
pdf.text(115, 175, valor_hora)
pdf.text(115, 190, termino)
pdf.text(115, 205, str(valor_total))

# Guardar el PDF
pdf.output("Presupuesto.pdf")
print("¡Presupuesto generado exitosamente!")
# Out:
# ¡Presupuesto generado exitosamente!
